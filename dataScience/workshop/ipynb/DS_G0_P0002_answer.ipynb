# %% [markdown]
# # DS_G0_P0002_answer
#
#             ## 0. 정답본 범위
#             - Gate: G0~G4 데이터사이언스 입구 고정
#             - Phase: Phase 1
#             - Topic: 통계·EDA 압축
#             - Problem notebook: `DS_G0_P0002.ipynb`
#             - Correct answers included: Yes
#             - Output language: Korean
#
#             이 파일은 정답본이다. 먼저 `DS_G0_P0002.ipynb`를 푼 뒤 채점 또는 오답 진단용으로 연다.
#
#             ## source anchors
#             - `DS_PDF07_STATS:p002:L007`
# - `DS_PDF07_STATS:p010:L004`
# - `DS_PDF07_STATS:p012:L004`
# - `DS_PDF06_VIS:p002:L005`
# - `DS_PDF06_VIS:p006:L005`
# - `DS_PDF06_VIS:p012:L007`

# %% [markdown]
# ## 기호 고정표
#
# 이 Phase 묶음에서는 아래 기호를 일관되게 쓴다.
#
# | 기호 | 뜻 | 사용 맥락 |
# |---|---|---|
# | `μ` | 모집단 평균, population mean | 전체 고객의 진짜 평균 사용시간 |
# | `σ`, `σ²` | 모집단 표준편차와 분산 | 전체 모집단의 퍼짐 |
# | `π` | 모집단 비율, population proportion | 전체 고객의 진짜 이탈률 |
# | `p` | 확률 또는 베르누이 성공확률 | 고객 1명이 이탈할 확률 |
# | `x̄` | 표본 평균, sample mean | 표본 고객의 평균 사용시간 |
# | `s`, `s²` | 표본 표준편차와 분산 | 표본의 퍼짐 |
# | `p̂` | 표본 비율, sample proportion | 표본 고객 중 이탈자 비율 |
# | `X` | 통계에서는 확률변수, ML에서는 feature matrix | 문맥으로 구분한다 |
# | `y` | target vector | 모델이 맞히려는 정답 |
#
# 주의: `π`는 모집단의 알 수 없는 진짜 비율이고, `p̂`는 표본에서 계산한 비율이다. 통계의 `X`와 ML의 `X`도 같은 글자지만 뜻이 다르다.

# %% [markdown]
# ## 1. 핵심 기준표
#             - 모집단/표본/모수/통계량을 구분한다.
# - 상대도수와 조건부비율을 계산하고 해석한다.
# - P(A|B)와 P(B|A)의 방향을 분리한다.
# - 변수 유형과 질문에 맞는 그래프를 선택한다.
# - 상관, binwidth, 색상 scale의 해석 한계를 표시한다.

# %% [markdown]
# ## 2. 문항별 정답

# %% [markdown]
# ## 문제 유형 A. 모수·통계량·기호 문제

# %% [markdown]
# ### A-1. 고객 사용시간 평균과 이탈률
#
#     **정답**
#
#     - `xbar_usage = 150 / 8 = 18.75`.
# - `phat_churn = 3 / 8 = 0.375`.
# - `xbar_usage`는 모집단 평균 `mu_usage`를 추정한다.
# - `phat_churn`은 모집단 이탈률 `pi_churn`을 추정한다.
# - `sigma`, `sigma^2`는 모집단 표준편차/분산이고 `s`, `s^2`는 표본 표준편차/분산이다.
# - 오답: 표본 8명의 결과를 전체 고객의 진짜 평균/이탈률로 단정하는 것.
#
#     **근거**
#     - 문제의 unit, target, feature, 통계량/모수 또는 metric을 먼저 고정한다.
#     - 관련 source anchor는 노트북 상단의 source anchors를 따른다.
#
#     **자주 하는 오답**
#     - 표본 통계량과 모집단 모수를 구분한다.를 놓치고 표면적인 column 이름이나 큰 metric 값만 보고 판단한다.
#
#     **최종 답안형**
#     - 계산 문제는 `공식 -> 대입 -> 계산 -> 단위/비율 -> 현실 해석` 순서로 쓴다.
#     - 구조 판단 문제는 `unit -> target -> feature -> 제외/주의 column -> 이유` 순서로 쓴다.

# %% [markdown]
# ### A-2. 제조 불량 베르누이 변수
#
#     **정답**
#
#     - `E[X] = p = 0.08`.
# - `p`는 제품 1개가 불량일 성공확률이다.
# - 통계의 `X`는 0/1 확률변수이고 ML의 `X`는 `rows x features` 입력행렬이다. 혼동하면 target/feature 구조를 잘못 잡는다.
#
#     **근거**
#     - 문제의 unit, target, feature, 통계량/모수 또는 metric을 먼저 고정한다.
#     - 관련 source anchor는 노트북 상단의 source anchors를 따른다.
#
#     **자주 하는 오답**
#     - 베르누이 성공확률 p와 feature matrix X를 구분한다.를 놓치고 표면적인 column 이름이나 큰 metric 값만 보고 판단한다.
#
#     **최종 답안형**
#     - 계산 문제는 `공식 -> 대입 -> 계산 -> 단위/비율 -> 현실 해석` 순서로 쓴다.
#     - 구조 판단 문제는 `unit -> target -> feature -> 제외/주의 column -> 이유` 순서로 쓴다.

# %% [markdown]
# ### A-3. 병원 재입원률 비교
#
#     **정답**
#
#     - A병원: `phat_A = 80 / 400 = 0.20`.
# - B병원: `phat_B = 36 / 120 = 0.30`.
# - 표본 기준으로는 B가 높아 보인다.
# - 그러나 표본 크기, 환자 중증도, 병원 구성 차이를 확인하지 않으면 원인을 단정할 수 없다.
# - 이는 인과 주장이 아니라 기술적 비교다.
#
#     **근거**
#     - 문제의 unit, target, feature, 통계량/모수 또는 metric을 먼저 고정한다.
#     - 관련 source anchor는 노트북 상단의 source anchors를 따른다.
#
#     **자주 하는 오답**
#     - 표본 비율 비교와 인과 주장을 분리한다.를 놓치고 표면적인 column 이름이나 큰 metric 값만 보고 판단한다.
#
#     **최종 답안형**
#     - 계산 문제는 `공식 -> 대입 -> 계산 -> 단위/비율 -> 현실 해석` 순서로 쓴다.
#     - 구조 판단 문제는 `unit -> target -> feature -> 제외/주의 column -> 이유` 순서로 쓴다.

# %% [markdown]
# ## 문제 유형 B. 도수분포·상대도수·분할표 문제

# %% [markdown]
# ### B-1. 앱 사용시간 상대도수
#
#     **정답**
#
#     - 상대도수: `0~10 = 6/30 = 0.20`, `10~20 = 9/30 = 0.30`, `20~30 = 8/30 = 0.267`, `30~40 = 5/30 = 0.167`, `40~50 = 2/30 = 0.067`.
# - 합은 반올림 전 1.0이고, 소수 반올림 후에는 약간 벗어날 수 있다.
# - 수치형 구간별 분포이므로 histogram이 적절하다.
#
#     **근거**
#     - 문제의 unit, target, feature, 통계량/모수 또는 metric을 먼저 고정한다.
#     - 관련 source anchor는 노트북 상단의 source anchors를 따른다.
#
#     **자주 하는 오답**
#     - relative frequency와 histogram을 연결한다.를 놓치고 표면적인 column 이름이나 큰 metric 값만 보고 판단한다.
#
#     **최종 답안형**
#     - 계산 문제는 `공식 -> 대입 -> 계산 -> 단위/비율 -> 현실 해석` 순서로 쓴다.
#     - 구조 판단 문제는 `unit -> target -> feature -> 제외/주의 column -> 이유` 순서로 쓴다.

# %% [markdown]
# ### B-2. 요금제와 이탈 분할표
#
#     **정답**
#
#     - Basic: `42 / 120 = 0.35`.
# - Plus: `30 / 200 = 0.15`.
# - Premium: `12 / 180 = 0.067`.
# - 각 요금제 row 안에서 계산한 행 기준 조건부비율이다.
# - Basic이 가장 높아 보이지만, 이 결과만으로 인과를 주장할 수 없다.
#
#     **근거**
#     - 문제의 unit, target, feature, 통계량/모수 또는 metric을 먼저 고정한다.
#     - 관련 source anchor는 노트북 상단의 source anchors를 따른다.
#
#     **자주 하는 오답**
#     - 분할표에서 행 기준 조건부비율과 인과 해석을 구분한다.를 놓치고 표면적인 column 이름이나 큰 metric 값만 보고 판단한다.
#
#     **최종 답안형**
#     - 계산 문제는 `공식 -> 대입 -> 계산 -> 단위/비율 -> 현실 해석` 순서로 쓴다.
#     - 구조 판단 문제는 `unit -> target -> feature -> 제외/주의 column -> 이유` 순서로 쓴다.

# %% [markdown]
# ### B-3. 채널별 구매 전환 조건부확률
#
#     **정답**
#
#     - `P(purchase=1 | Search) = 90 / 300 = 0.30`.
# - `P(Search | purchase=1) = 90 / (90 + 75 + 60) = 90 / 225 = 0.40`.
# - 첫 값은 Search 유입자의 전환율이고, 둘째 값은 구매자 중 Search 출신 비중이다.
# - 채널 효율을 비교하려면 보통 `P(purchase | channel)`이 중요하고, 구매자 구성 분석에는 `P(channel | purchase)`가 중요하다.
#
#     **근거**
#     - 문제의 unit, target, feature, 통계량/모수 또는 metric을 먼저 고정한다.
#     - 관련 source anchor는 노트북 상단의 source anchors를 따른다.
#
#     **자주 하는 오답**
#     - P(A|B)와 P(B|A)의 방향을 혼동하지 않는다.를 놓치고 표면적인 column 이름이나 큰 metric 값만 보고 판단한다.
#
#     **최종 답안형**
#     - 계산 문제는 `공식 -> 대입 -> 계산 -> 단위/비율 -> 현실 해석` 순서로 쓴다.
#     - 구조 판단 문제는 `unit -> target -> feature -> 제외/주의 column -> 이유` 순서로 쓴다.

# %% [markdown]
# ## 문제 유형 C. 그래프 선택·해석 한계 문제

# %% [markdown]
# ### C-1. income 단변량 분포
#
#     **정답**
#
#     - 적절한 그래프: histogram, KDE, boxplot.
# - histogram/KDE는 값의 몰림과 분포 모양을 보고, boxplot은 중앙값, IQR, 이상치 후보를 본다.
# - 히스토그램은 binwidth/bins에 따라 모양이 달라질 수 있어 한 설정만 보고 분포를 단정하면 안 된다.
#
#     **근거**
#     - 문제의 unit, target, feature, 통계량/모수 또는 metric을 먼저 고정한다.
#     - 관련 source anchor는 노트북 상단의 source anchors를 따른다.
#
#     **자주 하는 오답**
#     - 수치형 단변량에는 histogram/KDE/boxplot을 연결하고 binwidth 함정을 표시한다.를 놓치고 표면적인 column 이름이나 큰 metric 값만 보고 판단한다.
#
#     **최종 답안형**
#     - 계산 문제는 `공식 -> 대입 -> 계산 -> 단위/비율 -> 현실 해석` 순서로 쓴다.
#     - 구조 판단 문제는 `unit -> target -> feature -> 제외/주의 column -> 이유` 순서로 쓴다.

# %% [markdown]
# ### C-2. usage_time과 monthly_spend 관계
#
#     **정답**
#
#     - 산점도(scatter plot)가 적절하다.
# - 방향, 선형/비선형 형태, 이상치, 군집을 본다.
# - 상관이 보여도 `usage_time`이 `monthly_spend`를 원인으로 증가시킨다고 단정하면 안 된다.
#
#     **근거**
#     - 문제의 unit, target, feature, 통계량/모수 또는 metric을 먼저 고정한다.
#     - 관련 source anchor는 노트북 상단의 source anchors를 따른다.
#
#     **자주 하는 오답**
#     - 수치형-수치형 관계에는 scatter plot을 선택하고 상관과 인과를 구분한다.를 놓치고 표면적인 column 이름이나 큰 metric 값만 보고 판단한다.
#
#     **최종 답안형**
#     - 계산 문제는 `공식 -> 대입 -> 계산 -> 단위/비율 -> 현실 해석` 순서로 쓴다.
#     - 구조 판단 문제는 `unit -> target -> feature -> 제외/주의 column -> 이유` 순서로 쓴다.

# %% [markdown]
# ### C-3. plan_type, region, churn 다변량 패턴
#
#     **정답**
#
#     - `pd.crosstab([region, plan_type], churn, normalize="index")` 또는 pivot table로 조합별 이탈률을 만든다.
# - 행렬형 값은 heatmap으로 볼 수 있다.
# - normalize 기준과 색상 scale을 확인해야 하며, 색이 진하다고 인과나 중요도를 단정하면 안 된다.
#
#     **근거**
#     - 문제의 unit, target, feature, 통계량/모수 또는 metric을 먼저 고정한다.
#     - 관련 source anchor는 노트북 상단의 source anchors를 따른다.
#
#     **자주 하는 오답**
#     - crosstab/pivot과 heatmap을 연결하고 색상 scale 과해석을 피한다.를 놓치고 표면적인 column 이름이나 큰 metric 값만 보고 판단한다.
#
#     **최종 답안형**
#     - 계산 문제는 `공식 -> 대입 -> 계산 -> 단위/비율 -> 현실 해석` 순서로 쓴다.
#     - 구조 판단 문제는 `unit -> target -> feature -> 제외/주의 column -> 이유` 순서로 쓴다.

# %% [markdown]
# ## 3. 채점 기준
#                 - A-1: 핵심 개념 식별 30%, 계산/코드 판단 30%, 현실 해석 25%, 오답 위험 언급 15%
# - A-2: 핵심 개념 식별 30%, 계산/코드 판단 30%, 현실 해석 25%, 오답 위험 언급 15%
# - A-3: 핵심 개념 식별 30%, 계산/코드 판단 30%, 현실 해석 25%, 오답 위험 언급 15%
# - B-1: 핵심 개념 식별 30%, 계산/코드 판단 30%, 현실 해석 25%, 오답 위험 언급 15%
# - B-2: 핵심 개념 식별 30%, 계산/코드 판단 30%, 현실 해석 25%, 오답 위험 언급 15%
# - B-3: 핵심 개념 식별 30%, 계산/코드 판단 30%, 현실 해석 25%, 오답 위험 언급 15%
# - C-1: 핵심 개념 식별 30%, 계산/코드 판단 30%, 현실 해석 25%, 오답 위험 언급 15%
# - C-2: 핵심 개념 식별 30%, 계산/코드 판단 30%, 현실 해석 25%, 오답 위험 언급 15%
# - C-3: 핵심 개념 식별 30%, 계산/코드 판단 30%, 현실 해석 25%, 오답 위험 언급 15%
#
#                 부분점 기준:
#                 - 계산값만 맞고 해석이 없으면 감점한다.
#                 - 구조 판단에서 unit 또는 target을 쓰지 않으면 감점한다.
#                 - leakage 문제에서 정보 발생 시점이나 train/test 경계를 설명하지 않으면 감점한다.

# %% [markdown]
# ## 4. 오답튜터 기준표
#                 - 표본 평균을 모집단 평균으로 단정한다.: 오류가 나오면 정의를 다시 말하게 한 뒤, 같은 구조의 숫자나 column을 바꾼 재시도 문제를 낸다.
# - 표본 비율을 모집단 비율로 단정한다.: 오류가 나오면 정의를 다시 말하게 한 뒤, 같은 구조의 숫자나 column을 바꾼 재시도 문제를 낸다.
# - 행비율과 열비율을 바꿔 해석한다.: 오류가 나오면 정의를 다시 말하게 한 뒤, 같은 구조의 숫자나 column을 바꾼 재시도 문제를 낸다.
# - 히스토그램 binwidth를 바꾸지 않고 분포 모양을 단정한다.: 오류가 나오면 정의를 다시 말하게 한 뒤, 같은 구조의 숫자나 column을 바꾼 재시도 문제를 낸다.
# - 상관을 인과로 말한다.: 오류가 나오면 정의를 다시 말하게 한 뒤, 같은 구조의 숫자나 column을 바꾼 재시도 문제를 낸다.

# %% [markdown]
# ## 5. 다음 Phase 연결
# 다음은 Phase 2 지도학습 입구로 넘어가 X/y, train/test, metric, leakage를 푼다.

# %% [markdown]
# ## 최종 품질 체크
#                 - [x] Phase별 문제 유형이 3개 이하인가?
# - [x] 각 유형 문항이 3개 이하인가?
# - [x] 난이도 1.5 이상 문제에 계산 또는 함정이 있는가?
# - [x] μ, π, x̄, p̂, X, y가 모두 등장하는가?
# - [x] feature/target 구분 문제가 있는가?
# - [x] relative frequency 또는 contingency table 문제가 있는가?
# - [x] chart selection 문제가 있는가?
# - [x] train/test leakage 문제가 있는가?
# - [x] confusion matrix 문제가 있는가?
# - [x] 각 문제에 현실 해석 질문이 있는가?
