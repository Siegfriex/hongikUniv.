# %% [markdown]
# # DS_G0_P0001
#
#             ## 0. 학습 범위
#             - Gate: G0~G4 데이터사이언스 입구 고정
#             - Phase: Phase 0
#             - Topic: 데이터 spine·기호 세팅
#             - Goal: 데이터를 unit, row/column, feature/target, identifier, leakage 후보, mu/pi/xbar/phat/X/y로 번역한다.
#             - Source basis:
#             - dataScience/rag_applied_flat_pack/DS_PDF06_CODE__04_rag.md
# - dataScience/rag_applied_flat_pack/DS_PDF06_VIS__04_rag.md
# - dataScience/rag_applied_flat_pack/DS_PDF07_STATS__04_rag.md
# - dataScience/rag_applied_flat_pack/DS_PDF08_ML1__04_rag.md
#             - Output language: Korean
#             - Code mode: hint_only
#
#             ## source anchors
#             - `DS_PDF06_CODE:p013:L007`
# - `DS_PDF08_ML1:p045:L004`
# - `DS_PDF06_CODE:p036:L013`
# - `DS_PDF07_STATS:p002:L007`

# %% [markdown]
# ## 1. 작성 규칙
# - 풀이용 노트북에는 정답이 포함되어 있지 않다.
# - 문항별로 `개념 -> 계산 또는 판단 -> 현실 해석 -> 오답 위험` 순서로 답한다.
# - code cell은 힌트 전용이다. 빈칸, TODO, 확인 방향만 제공한다.
# - 답안을 쓰기 전 항상 `unit -> row/column -> feature/target -> 통계량/모수 -> EDA -> X/y -> train/test -> metric` 중 현재 문제가 어디에 있는지 표시한다.

# %% [markdown]
# ## 2. 채점 기준
#             - unit of analysis와 row meaning을 먼저 쓴다.
# - target, feature 후보, 제외 후보를 분리한다.
# - mu/pi는 모집단 모수, xbar/phat는 표본 통계량으로 구분한다.
# - 통계의 X와 ML의 feature matrix X를 문맥으로 구분한다.
# - random_state는 재현성 장치로 해석한다.

# %% [markdown]
# ## 공통 mock customer dataset
# 실제 데이터가 아닌 학습용 mock schema다.
#
# ```text
# customer_id, age, income, usage_time, payment_delay, complaints,
# plan_type, region, tenure_months, monthly_spend, review_text, churn
# ```
#
# 기본 해석:
# - row meaning: 고객 1명
# - target 후보: `churn`
# - feature 후보: 고객의 행동, 결제, 요금제, 지역, 사용량 관련 변수
# - 제외 후보: `customer_id`
# - text feature 후보: `review_text`
# - `churn`은 0/1 범주형 target이므로 classification 문제

# %% [markdown]
# ## 기호 고정표
#
# 이 Phase 묶음에서는 아래 기호를 일관되게 쓴다.
#
# | 기호 | 뜻 | 사용 맥락 |
# |---|---|---|
# | `μ` | 모집단 평균, population mean | 전체 고객의 진짜 평균 사용시간 |
# | `σ`, `σ²` | 모집단 표준편차와 분산 | 전체 모집단의 퍼짐 |
# | `π` | 모집단 비율, population proportion | 전체 고객의 진짜 이탈률 |
# | `p` | 확률 또는 베르누이 성공확률 | 고객 1명이 이탈할 확률 |
# | `x̄` | 표본 평균, sample mean | 표본 고객의 평균 사용시간 |
# | `s`, `s²` | 표본 표준편차와 분산 | 표본의 퍼짐 |
# | `p̂` | 표본 비율, sample proportion | 표본 고객 중 이탈자 비율 |
# | `X` | 통계에서는 확률변수, ML에서는 feature matrix | 문맥으로 구분한다 |
# | `y` | target vector | 모델이 맞히려는 정답 |
#
# 주의: `π`는 모집단의 알 수 없는 진짜 비율이고, `p̂`는 표본에서 계산한 비율이다. 통계의 `X`와 ML의 `X`도 같은 글자지만 뜻이 다르다.

# %% [markdown]
# ## 3. 문제 세트

# %% [markdown]
# ## 문제 유형 A. 데이터 구조 번역 문제

# %% [markdown]
# ### A-1. Customer churn 도메인 / 난이도 1.5
#
#     **문제 맥락**
#     고객 이탈 예측을 위한 작은 테이블 설계를 검토한다.
#
#     **주어진 데이터 또는 숫자**
#     `customer_id, age, income, usage_time, payment_delay, complaints, plan_type, churn`
#
#     **질문**
#     1. unit of analysis는 무엇인가?
# 2. row 하나는 현실에서 무엇인가?
# 3. target은 무엇인가?
# 4. feature 후보는 무엇인가?
# 5. feature로 쓰면 위험하거나 의미 없는 column은 무엇인가?
#
#     **의도된 함정 또는 확인 개념**
#     identifier를 feature로 넣는 오류를 잡는다.
#
#     **튜터가 학생에게 던질 첫 질문**
#     이 데이터에서 row 하나가 현실의 누구 또는 무엇을 뜻하나?

# %%
# 힌트 전용: 정답을 출력하지 않는다.
columns = ["customer_id", "age", "income", "usage_time", "payment_delay", "complaints", "plan_type", "churn"]
# TODO: unit, target_col, feature_candidates, excluded_cols를 직접 적어라.

# %% [markdown]
# ### 내 답안: A-1
#
# - 현재 노드/개념:
# - unit:
# - row/column 해석:
# - feature/target 또는 모수/통계량:
# - 계산 또는 판단:
# - 현실 해석:
# - 오답 위험:

# %% [markdown]
# ### A-2. 병원 예약 노쇼 도메인 / 난이도 2.0
#
#     **문제 맥락**
#     예약 환자의 노쇼 여부를 예측하려 한다.
#
#     **주어진 데이터 또는 숫자**
#     `patient_id, age, department, previous_no_show_count, appointment_day, reminder_sent, no_show`
#
#     **질문**
#     1. target은 무엇인가?
# 2. classification인가 regression인가?
# 3. `appointment_day`는 그대로 써도 되는가, 전처리가 필요한가?
# 4. `reminder_sent`는 feature로 쓸 수 있는가? 정보 발생 시점을 기준으로 설명하라.
#
#     **의도된 함정 또는 확인 개념**
#     feature는 column 이름만 보고 고르지 않고 정보 발생 시점을 확인한다.
#
#     **튜터가 학생에게 던질 첫 질문**
#     예측 시점에 이미 알고 있던 정보와 예측 이후에 생긴 정보를 어떻게 나눌까?

# %%
# 힌트 전용
# 1) target 후보를 먼저 찾는다.
# 2) target의 값이 범주인지 연속값인지 판단한다.
# 3) 날짜 column은 보통 year/month/day/weekday 같은 파생변수 후보가 된다.
# 4) reminder_sent의 기록 시점이 예약 전인지 예약 후인지 확인한다.

# %% [markdown]
# ### 내 답안: A-2
#
# - 현재 노드/개념:
# - unit:
# - row/column 해석:
# - feature/target 또는 모수/통계량:
# - 계산 또는 판단:
# - 현실 해석:
# - 오답 위험:

# %% [markdown]
# ### A-3. 온라인 강의 수료 예측 도메인 / 난이도 2.5
#
#     **문제 맥락**
#     1주차 종료 시점에 온라인 강의 최종 수료 여부를 예측하려 한다.
#
#     **주어진 데이터 또는 숫자**
#     `student_id, login_count_week1, video_watch_time_week1, quiz_score_final, assignment_submitted, completed`
#
#     **질문**
#     1. `completed`를 예측할 때 `quiz_score_final`은 feature로 써도 되는가?
# 2. 왜 leakage 후보인지 설명하라.
# 3. 모델링 시점이 1주차 종료 시점이면 feature로 쓸 수 있는 column만 골라라.
#
#     **의도된 함정 또는 확인 개념**
#     사후 정보와 target leakage를 구분한다.
#
#     **튜터가 학생에게 던질 첫 질문**
#     1주차 종료 시점에 실제로 관측 가능한 column만 남기면 무엇이 남나?

# %%
# 힌트 전용
# 예측 기준 시점: 1주차 종료 시점
# TODO: before_prediction_cols와 after_prediction_cols를 나눠라.

# %% [markdown]
# ### 내 답안: A-3
#
# - 현재 노드/개념:
# - unit:
# - row/column 해석:
# - feature/target 또는 모수/통계량:
# - 계산 또는 판단:
# - 현실 해석:
# - 오답 위험:

# %% [markdown]
# ## 문제 유형 B. 기호 매핑 문제

# %% [markdown]
# ### B-1. 이탈률의 pi와 phat / 난이도 1.5
#
#     **문제 맥락**
#     전체 고객 50,000명 중 진짜 이탈률은 모른다. 표본 400명에서 이탈 고객이 92명이다.
#
#     **주어진 데이터 또는 숫자**
#     `population_size=50000`, `sample_size=400`, `churn_count=92`
#
#     **질문**
#     1. 모집단 비율 기호를 써라.
# 2. 표본 비율을 계산하라.
# 3. `pi`와 `phat`의 차이를 문장으로 설명하라.
#
#     **의도된 함정 또는 확인 개념**
#     표본 비율을 모집단 비율로 단정하지 않는다.
#
#     **튜터가 학생에게 던질 첫 질문**
#     지금 계산할 수 있는 값은 전체의 진짜 값인가, 표본에서 나온 값인가?

# %%
# 힌트 전용
sample_size = 400
churn_count = 92
# phat = churn_count / sample_size
# pi는 계산값이 아니라 모집단의 알 수 없는 진짜 비율을 뜻한다.

# %% [markdown]
# ### 내 답안: B-1
#
# - 현재 노드/개념:
# - unit:
# - row/column 해석:
# - feature/target 또는 모수/통계량:
# - 계산 또는 판단:
# - 현실 해석:
# - 오답 위험:

# %% [markdown]
# ### B-2. 사용시간 평균의 mu와 xbar / 난이도 1.5
#
#     **문제 맥락**
#     표본 고객 5명의 `usage_time`이 주어졌다.
#
#     **주어진 데이터 또는 숫자**
#     `12, 18, 21, 9, 30`
#
#     **질문**
#     1. 표본 평균 `xbar`를 계산하라.
# 2. 이 값은 어떤 모수의 추정값인가?
# 3. 이 값을 전체 고객 평균이라고 단정하면 왜 틀리는가?
#
#     **의도된 함정 또는 확인 개념**
#     xbar와 mu를 구분한다.
#
#     **튜터가 학생에게 던질 첫 질문**
#     계산한 평균은 표본에서 나온 값인가, 모집단 전체의 값인가?

# %%
# 힌트 전용
values = [12, 18, 21, 9, 30]
# xbar = sum(values) / len(values)

# %% [markdown]
# ### 내 답안: B-2
#
# - 현재 노드/개념:
# - unit:
# - row/column 해석:
# - feature/target 또는 모수/통계량:
# - 계산 또는 판단:
# - 현실 해석:
# - 오답 위험:

# %% [markdown]
# ### B-3. 베르누이 확률변수 X와 ML feature matrix X / 난이도 2.0
#
#     **문제 맥락**
#     고객 이탈 여부를 확률변수 `X`로 둔다. `X=1`이면 churn, `X=0`이면 non-churn이다.
#
#     **주어진 데이터 또는 숫자**
#     `p = 0.28`
#
#     **질문**
#     1. `E[X]`는 얼마인가?
# 2. 이 값이 현실에서 뜻하는 것은 무엇인가?
# 3. 이 `X`와 ML에서의 feature matrix `X`는 같은 뜻인가?
#
#     **의도된 함정 또는 확인 개념**
#     통계 확률변수 X와 ML 입력행렬 X를 문맥으로 구분한다.
#
#     **튜터가 학생에게 던질 첫 질문**
#     여기서 X는 한 고객의 0/1 결과인가, 여러 feature column을 가진 행렬인가?

# %%
# 힌트 전용
# Bernoulli random variable: X in {0, 1}
# E[X] = p
# ML feature matrix X는 보통 rows x features 형태다.

# %% [markdown]
# ### 내 답안: B-3
#
# - 현재 노드/개념:
# - unit:
# - row/column 해석:
# - feature/target 또는 모수/통계량:
# - 계산 또는 판단:
# - 현실 해석:
# - 오답 위험:

# %% [markdown]
# ## 문제 유형 C. 코드 skeleton 판단 문제

# %% [markdown]
# ### C-1. X/y skeleton 채우기 / 난이도 1.5
#
#     **문제 맥락**
#     고객 이탈 예측용 DataFrame에서 입력과 정답을 분리하려 한다.
#
#     **주어진 데이터 또는 숫자**
#     빈칸이 있는 pandas skeleton
#
#     **질문**
#     1. `X`에 들어갈 객체를 채워라.
# 2. `y`에 들어갈 객체를 채워라.
# 3. `X`와 `y`가 각각 현실에서 무엇을 뜻하는지 한 문장으로 설명하라.
#
#     **의도된 함정 또는 확인 개념**
#     feature matrix와 target vector를 분리한다.
#
#     **튜터가 학생에게 던질 첫 질문**
#     무엇을 근거로 무엇을 맞히는 구조인가?

# %%
# 힌트 전용
feature_cols = ["age", "income", "usage_time", "payment_delay", "complaints"]
X = df[_____]
y = df[_____]

# %% [markdown]
# ### 내 답안: C-1
#
# - 현재 노드/개념:
# - unit:
# - row/column 해석:
# - feature/target 또는 모수/통계량:
# - 계산 또는 판단:
# - 현실 해석:
# - 오답 위험:

# %% [markdown]
# ### C-2. feature list에서 제거할 column 찾기 / 난이도 2.0
#
#     **문제 맥락**
#     아래 feature list를 그대로 모델에 넣으려 한다.
#
#     **주어진 데이터 또는 숫자**
#     `customer_id, age, income, usage_time, payment_delay, complaints, plan_type, churn`
#
#     **질문**
#     1. 반드시 제거해야 할 column을 고르라.
# 2. 각 column을 제거해야 하는 이유를 설명하라.
# 3. 남은 feature가 모두 바로 모델에 들어갈 수 있는지 dtype 관점에서 설명하라.
#
#     **의도된 함정 또는 확인 개념**
#     identifier, target 포함, 범주형 인코딩 필요성을 구분한다.
#
#     **튜터가 학생에게 던질 첫 질문**
#     이 column이 새 고객에게 일반화 가능한 설명변수인가, 정답 자체인가, 식별자인가?

# %%
# 힌트 전용
feature_cols = ["customer_id", "age", "income", "usage_time", "payment_delay", "complaints", "plan_type", "churn"]
# TODO: 제거 후보를 identifier / target / dtype 처리 필요로 나눠라.

# %% [markdown]
# ### 내 답안: C-2
#
# - 현재 노드/개념:
# - unit:
# - row/column 해석:
# - feature/target 또는 모수/통계량:
# - 계산 또는 판단:
# - 현실 해석:
# - 오답 위험:

# %% [markdown]
# ### C-3. random_state 해석 / 난이도 2.0
#
#     **문제 맥락**
#     같은 데이터로 모델 비교 실험을 반복하려 한다.
#
#     **주어진 데이터 또는 숫자**
#     `train_test_split(..., test_size=0.2, random_state=42)`
#
#     **질문**
#     1. `random_state=42`는 단순 장식 코드인가?
# 2. 이 값을 빼면 어떤 문제가 생길 수 있는가?
# 3. 모델 A와 모델 B를 비교할 때 왜 같은 split이 필요한가?
#
#     **의도된 함정 또는 확인 개념**
#     난수 고정은 재현성과 공정한 비교를 위한 장치다.
#
#     **튜터가 학생에게 던질 첫 질문**
#     실험을 다시 실행했을 때 train/test 구성이 바뀌면 무엇을 비교하기 어려워질까?

# %%
# 힌트 전용
# random_state는 split, sampling, initialization의 재현성과 연결된다.
# TODO: 결과 재현 / 모델 비교 / 난수 변동을 구분해서 써라.

# %% [markdown]
# ### 내 답안: C-3
#
# - 현재 노드/개념:
# - unit:
# - row/column 해석:
# - feature/target 또는 모수/통계량:
# - 계산 또는 판단:
# - 현실 해석:
# - 오답 위험:

# %% [markdown]
# ## 오답 위험 요약
#                 - 식별자인 `customer_id`를 feature로 넣는다.
# - `churn` 같은 target을 `X`에 섞는다.
# - `phat`를 `pi`라고 단정한다.
# - 통계 확률변수 `X`와 ML feature matrix `X`를 같은 것으로 본다.
# - `random_state`를 결과와 무관한 장식으로 본다.

# %% [markdown]
# ## 튜터용 힌트
#                 - 항상 unit -> row -> column -> target -> feature 순서로 묻는다.
# - 시간 기준점을 물어 leakage를 진단한다.
# - 기호가 나오면 모집단 값인지 표본 값인지 먼저 말하게 한다.

# %% [markdown]
# ## 정답본 분리 여부
# - 정답본은 `DS_G0_P0001_answer.ipynb`에만 있다.
# - 먼저 이 문제지를 풀고, 채점 또는 오답 진단 때만 정답본을 연다.

# %% [markdown]
# ## 최종 품질 체크
#                 - [x] Phase별 문제 유형이 3개 이하인가?
# - [x] 각 유형 문항이 3개 이하인가?
# - [x] 난이도 1.5 이상 문제에 계산 또는 함정이 있는가?
# - [x] μ, π, x̄, p̂, X, y가 모두 등장하는가?
# - [x] feature/target 구분 문제가 있는가?
# - [x] relative frequency 또는 contingency table 문제가 있는가?
# - [x] chart selection 문제가 있는가?
# - [x] train/test leakage 문제가 있는가?
# - [x] confusion matrix 문제가 있는가?
# - [x] 각 문제에 현실 해석 질문이 있는가?
