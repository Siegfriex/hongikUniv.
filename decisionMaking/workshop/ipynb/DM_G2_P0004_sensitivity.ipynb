# %% [markdown]
# # DM_G2_P0004_sensitivity
#
# ## 0. 학습 범위
#
# - Course code: DM
# - Gate: G2
# - Phase: P0004
# - Topic: Ch.5 민감도 분석, reduced cost, shadow price, allowable range, Solver sensitivity report
# - Goal: LP 최적해 이후 Solver sensitivity report를 변수 질문과 제약/RHS 질문으로 분리해 해석한다.
# - Source basis: `DM_PDF02__04_rag.md`, `DM_PDF05__04_rag.md`
# - Output language: Korean
# - Code mode: hint_only
# - Web grounding: no

# %% [markdown]
# ## 1. 작성 규칙
#
# - 풀이용 노트북에는 최종 정답을 적지 않는다.
# - 각 문항에는 `node_id`와 `source anchor`를 포함한다.
# - reduced cost는 변수 질문, shadow price는 제약/RHS 질문으로 구분한다.
# - allowable increase/decrease 밖의 변화는 기존 보고서만으로 단정하지 않는다.
# - 코드 셀은 힌트 또는 빈 계산 보조용이며 최종 수치 판정을 출력하지 않는다.

# %% [markdown]
# ## 2. 채점 기준
#
# - sensitivity report의 Variable Cells/Constraints 구분: 20점
# - reduced cost와 shadow price 분리: 20점
# - allowable range 적용: 25점
# - binding/nonbinding 및 complementary slackness 해석: 15점
# - Solver mapping/source anchor/node_id: 10점
# - 오답진단: 10점

# %% [markdown]
# ## 3. 민감도 분석 기준표
#
# | 질문 | 봐야 할 위치 | 핵심 값 |
# | --- | --- | --- |
# | 현재 0인 변수가 들어올 수 있는가? | Variable Cells | Reduced Cost, Objective Coefficient range |
# | 자원을 1단위 더 주면 목적값이 어떻게 변하는가? | Constraints | Shadow Price |
# | 지금 shadow price를 그대로 써도 되는가? | Constraints | Allowable Increase/Decrease |
# | 현재 basis가 유지되는가? | Variable/Constraint range | 허용범위 |
# | 제약이 남는가? | Constraints | Slack = RHS - Final LHS |

# %% [markdown]
# ## 4. 문제 세트
#
# ### 공통 상황: 웨어러블 생산계획 민감도 보고서
#
# 한 전자기기 회사가 세 제품을 생산한다.
#
# - `x1` = 스마트밴드 생산량
# - `x2` = 무선이어셋 생산량
# - `x3` = 헬스센서 생산량
#
# ```text
# Maximize z = 40x1 + 30x2 + 22x3
#
# subject to
# 2x1 + x2 + x3 <= 100     조립시간 R1
# x1 + 2x2 + 2x3 <= 120    검사시간 R2
# x1 <= 55                 스마트밴드 수요상한 R3
# x2 <= 70                 무선이어셋 수요상한 R4
# x3 <= 35                 헬스센서 수요상한 R5
# x1, x2, x3 >= 0
# ```
#
# Variable Cells:
#
# | 변수 | Final Value | Reduced Cost | Objective Coefficient | Allowable Increase | Allowable Decrease |
# | -- | ----------: | -----------: | --------------------: | -----------------: | -----------------: |
# | x1 | 26.6667 | 0 | 40 | 20 | 25 |
# | x2 | 46.6667 | 0 | 30 | 50 | 8 |
# | x3 | 0 | -8 | 22 | 8 | 1E+30 |
#
# Constraints:
#
# | 제약 | Final LHS | Shadow Price | RHS | Allowable Increase | Allowable Decrease |
# | --- | ---: | ---: | ---: | ---: | ---: |
# | R1 조립시간 | 100 | 16.6667 | 100 | 42.5 | 40 |
# | R2 검사시간 | 120 | 6.6667 | 120 | 35 | 70 |
# | R3 x1 수요상한 | 26.6667 | 0 | 55 | 1E+30 | 28.3333 |
# | R4 x2 수요상한 | 46.6667 | 0 | 70 | 1E+30 | 23.3333 |
# | R5 x3 수요상한 | 0 | 0 | 35 | 1E+30 | 35 |

# %% [markdown]
# ### 문항 1. 기본 모형 해석
#
# 요구:
#
# 1. decision variables를 정의하라.
# 2. objective function의 현실 의미를 쓰라.
# 3. 각 constraint의 LHS와 RHS 의미를 쓰라.
# 4. changing cells, target cell, constraint LHS cells, RHS cells를 Solver 언어로 번역하라.
# 5. 이 문제가 sensitivity report를 사용할 수 있는 LP인지 설명하라.
#
# - node_id: `n_DM_PDF02.sensitivity_analysis`
# - source anchor: `DM_PDF02:p023:L001`

# %%
# 힌트:
# - Variable Cells 섹션은 변수 질문이다.
# - Constraints 섹션은 자원/RHS 질문이다.
# - shadow price는 RHS 변화가 allowable range 안에 있을 때만 적용한다.
# - reduced cost는 현재 0인 변수가 들어오기 위해 필요한 목적계수 개선량이다.
# - nonbinding constraint의 shadow price는 보통 0이다.

# %% [markdown]
# ### 내 답안
#
# - decision variables:
# - objective 의미:
# - constraint LHS/RHS 의미:
# - Solver mapping:
# - LP sensitivity 가능 여부:
# - node_id/source anchor:

# %% [markdown]
# ### 문항 2. binding/nonbinding 판정
#
# 요구:
#
# 1. 각 제약식 R1~R5가 binding인지 nonbinding인지 판정하라.
# 2. slack 값을 계산하라.
# 3. nonbinding 제약의 shadow price가 0인 이유를 현실 언어로 설명하라.
# 4. complementary slackness 관점에서 slack과 shadow price의 관계를 설명하라.
#
# - node_id: `n_DM_PDF02.shadow_price`, `n_DM_PDF05.complementary_slackness`
# - source anchors: `DM_PDF02:p030:L002`, `DM_PDF05:p030:L002`

# %%
# 힌트:
# - Variable Cells 섹션은 변수 질문이다.
# - Constraints 섹션은 자원/RHS 질문이다.
# - shadow price는 RHS 변화가 allowable range 안에 있을 때만 적용한다.
# - reduced cost는 현재 0인 변수가 들어오기 위해 필요한 목적계수 개선량이다.
# - nonbinding constraint의 shadow price는 보통 0이다.

# %% [markdown]
# ### 내 답안
#
# - R1~R5 binding 판정:
# - slack 계산:
# - nonbinding shadow price 해석:
# - complementary slackness:
# - node_id/source anchors:

# %% [markdown]
# ### 문항 3. shadow price 적용
#
# 요구:
#
# 1. 조립시간 R1을 20시간 늘리면 목적값은 어떻게 변하는지 계산하라.
# 2. 검사시간 R2를 50시간 줄이면 목적값은 어떻게 변하는지 계산하라.
# 3. R1을 50시간 늘리는 경우 기존 shadow price를 그대로 적용할 수 있는지 판정하라.
# 4. 허용범위 밖 변화에서는 왜 재해찾기가 필요한지 설명하라.
#
# - node_id: `n_DM_PDF02.shadow_price`, `n_DM_PDF02.sensitivity_analysis`
# - source anchors: `DM_PDF02:p030:L002`, `DM_PDF02:p031:L002`

# %%
# 힌트:
# - Variable Cells 섹션은 변수 질문이다.
# - Constraints 섹션은 자원/RHS 질문이다.
# - shadow price는 RHS 변화가 allowable range 안에 있을 때만 적용한다.
# - reduced cost는 현재 0인 변수가 들어오기 위해 필요한 목적계수 개선량이다.
# - nonbinding constraint의 shadow price는 보통 0이다.

# %% [markdown]
# ### 내 답안
#
# - R1 +20 변화:
# - R2 -50 변화:
# - R1 +50 적용 가능 여부:
# - 범위 밖 재해찾기 이유:
# - node_id/source anchors:

# %% [markdown]
# ### 문항 4. reduced cost 해석
#
# 요구:
#
# 1. `x3`의 reduced cost = -8이 의미하는 바를 설명하라.
# 2. `x3`가 현재 생산되지 않는 이유를 자원가치 관점에서 설명하라.
# 3. `x3`의 단위이익이 22에서 28로 증가하면 현재 최적 생산계획이 유지되는지 판정하라.
# 4. `x3`의 단위이익이 22에서 33으로 증가하면 왜 기존 sensitivity report만으로 단정할 수 없는지 설명하라.
#
# - node_id: `n_DM_PDF02.reduced_cost`
# - source anchors: `DM_PDF02:p028:L002`, `DM_PDF02:p032:L002`

# %%
# 힌트:
# - Variable Cells 섹션은 변수 질문이다.
# - Constraints 섹션은 자원/RHS 질문이다.
# - shadow price는 RHS 변화가 allowable range 안에 있을 때만 적용한다.
# - reduced cost는 현재 0인 변수가 들어오기 위해 필요한 목적계수 개선량이다.
# - nonbinding constraint의 shadow price는 보통 0이다.

# %% [markdown]
# ### 내 답안
#
# - reduced cost 의미:
# - x3 미생산 이유:
# - 이익 28 판정:
# - 이익 33 판정:
# - node_id/source anchors:

# %% [markdown]
# ### 문항 5. 목적함수 계수 허용범위
#
# 요구:
#
# 1. `x1`의 objective coefficient가 40에서 55로 증가하면 현재 basis가 유지되는지 판정하라.
# 2. `x2`의 objective coefficient가 30에서 21로 감소하면 현재 basis가 유지되는지 판정하라.
# 3. “변수 값은 유지될 수 있지만 objective value는 바뀐다”는 말을 설명하라.
# 4. objective coefficient 변화와 RHS 변화의 차이를 설명하라.
#
# - node_id: `n_DM_PDF02.sensitivity_analysis`, `n_DM_PDF02.reduced_cost`
# - source anchor: `DM_PDF02:p033:L002`

# %%
# 힌트:
# - Variable Cells 섹션은 변수 질문이다.
# - Constraints 섹션은 자원/RHS 질문이다.
# - shadow price는 RHS 변화가 allowable range 안에 있을 때만 적용한다.
# - reduced cost는 현재 0인 변수가 들어오기 위해 필요한 목적계수 개선량이다.
# - nonbinding constraint의 shadow price는 보통 0이다.

# %% [markdown]
# ### 내 답안
#
# - x1 계수 변화 판정:
# - x2 계수 변화 판정:
# - 값 유지/objective 변화 설명:
# - objective coefficient vs RHS 변화:
# - node_id/source anchor:

# %% [markdown]
# ### 문항 6. 오답 진단: shadow price 무제한 적용
#
# 학생 답안:
#
# > “R1의 shadow price가 16.6667이므로 R1이 100시간 늘어나면 목적값은 무조건 1666.67 증가한다.”
#
# 요구:
#
# 1. 맞는 부분을 쓰라.
# 2. 틀린 부분을 지적하라.
# 3. 최소 수정안을 제시하라.
# 4. 허용가능 증가치와 연결해 설명하라.
#
# - node_id: `n_DM_PDF02.shadow_price`
# - source anchor: `DM_PDF02:p031:L002`

# %%
# 힌트:
# - Variable Cells 섹션은 변수 질문이다.
# - Constraints 섹션은 자원/RHS 질문이다.
# - shadow price는 RHS 변화가 allowable range 안에 있을 때만 적용한다.
# - reduced cost는 현재 0인 변수가 들어오기 위해 필요한 목적계수 개선량이다.
# - nonbinding constraint의 shadow price는 보통 0이다.

# %% [markdown]
# ### 내 답안
#
# - 맞는 부분:
# - 틀린 부분:
# - 최소 수정안:
# - 허용가능 증가치 연결:
# - node_id/source anchor:

# %% [markdown]
# ### 문항 7. 오답 진단: reduced cost와 shadow price 혼동
#
# 학생 답안:
#
# > “`x3`의 reduced cost가 -8이므로 R1 조립시간을 1시간 늘리면 목적값이 8 감소한다.”
#
# 요구:
#
# 1. 이 답안이 변수 질문과 제약/RHS 질문을 어떻게 혼동했는지 설명하라.
# 2. `x3` reduced cost가 답하는 올바른 질문을 쓰라.
# 3. R1 조립시간 1시간 변화는 어떤 값을 봐야 하는지 쓰라.
# 4. Solver report에서 두 값이 각각 어느 섹션에 있는지 설명하라.
#
# - node_id: `n_DM_PDF02.reduced_cost`, `n_DM_PDF02.shadow_price`
# - source anchors: `DM_PDF02:p032:L002`, `DM_PDF05:p032:L002`

# %%
# 힌트:
# - Variable Cells 섹션은 변수 질문이다.
# - Constraints 섹션은 자원/RHS 질문이다.
# - shadow price는 RHS 변화가 allowable range 안에 있을 때만 적용한다.
# - reduced cost는 현재 0인 변수가 들어오기 위해 필요한 목적계수 개선량이다.
# - nonbinding constraint의 shadow price는 보통 0이다.

# %% [markdown]
# ### 내 답안
#
# - 혼동 지점:
# - reduced cost가 답하는 질문:
# - R1 변화에서 볼 값:
# - Solver report 섹션:
# - node_id/source anchors:

# %% [markdown]
# ### 문항 8. sensitivity report 라우팅
#
# 다음 질문을 `Variable Cells`, `Constraints`, `final tableau/duality`, `재해찾기 필요` 중 어디로 라우팅할지 쓰라.
#
# A. 현재 생산하지 않는 헬스센서를 생산하려면 단위이익이 얼마나 좋아져야 하는가?
# B. 조립시간을 5시간 더 확보하면 목적값이 어떻게 변하는가?
# C. 검사시간을 100시간 줄이면 기존 shadow price를 적용할 수 있는가?
# D. nonbinding demand upper bound의 shadow price가 0인 이유는 무엇인가?
#
# - node_id: `n_DM_PDF02.solver_sensitivity_report`, `n_DM_PDF05.primal_dual_mapping`
# - source anchors: `DM_PDF02:p027:L002`, `DM_PDF05:p032:L002`

# %%
# 힌트:
# - Variable Cells 섹션은 변수 질문이다.
# - Constraints 섹션은 자원/RHS 질문이다.
# - shadow price는 RHS 변화가 allowable range 안에 있을 때만 적용한다.
# - reduced cost는 현재 0인 변수가 들어오기 위해 필요한 목적계수 개선량이다.
# - nonbinding constraint의 shadow price는 보통 0이다.

# %% [markdown]
# ### 내 답안
#
# - A 라우팅:
# - B 라우팅:
# - C 라우팅:
# - D 라우팅:
# - final tableau/duality 연결:
# - node_id/source anchors:

# %% [markdown]
# ### 문항 9. G1에서 G2로 넘어가는 연결
#
# 요구:
#
# 1. final tableau에서 reduced cost와 shadow price가 어디서 오는지 설명하라.
# 2. complementary slackness가 binding/nonbinding 해석과 어떻게 연결되는지 설명하라.
# 3. P0004가 왜 다음 Phase인 transportation sensitivity와 연결되는지 설명하라.
#
# - node_id: `n_DM_PDF02.sensitivity_analysis`, `n_DM_PDF05.complementary_slackness`
# - source anchors: `DM_PDF02:p027:L002`, `DM_PDF05:p030:L002`, `DM_PDF05:p032:L002`

# %%
# 힌트:
# - Variable Cells 섹션은 변수 질문이다.
# - Constraints 섹션은 자원/RHS 질문이다.
# - shadow price는 RHS 변화가 allowable range 안에 있을 때만 적용한다.
# - reduced cost는 현재 0인 변수가 들어오기 위해 필요한 목적계수 개선량이다.
# - nonbinding constraint의 shadow price는 보통 0이다.

# %% [markdown]
# ### 내 답안
#
# - final tableau 연결:
# - complementary slackness 연결:
# - transportation sensitivity 연결:
# - node_id/source anchors:
