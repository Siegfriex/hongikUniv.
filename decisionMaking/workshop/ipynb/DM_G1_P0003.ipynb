# %% [markdown]
# # DM_G1_P0003
#
# ## 0. 학습 범위
#
# - Gate: G1
# - Phase: P0003
# - Topic: Big-M 방법과 쌍대성 브릿지
# - Goal: Big-M으로 artificial variable을 제거하는 사고를 이해하고, primal-dual mapping과 weak/strong duality, complementary slackness로 넘어간다.
# - Source basis:
#   - `DM_PDF05__04_rag.md`
#   - `DM_PDF05__03_concept_node_index.md`
#   - `DM_PDF05__02_rawdata_develop.md`
#   - `DM_PDF05__01_pdf_transcript.md`
#   - `DM_PDF01__04_rag.md`
#   - `DM_PDF02__04_rag.md`
# - Output language: Korean
# - Code mode: hint_only
# - Gate note: 이 Phase는 G1의 Big-M 중심이지만 G2 sensitivity/duality로 넘어가는 bridge다.

# %% [markdown]
# ## 1. 작성 규칙
#
# - 풀이용 노트북에는 최종 정답을 적지 않는다.
# - 각 문항의 `node_id`와 `source anchor`를 확인한 뒤 답안을 작성한다.
# - 계산보다 판정 이유, Solver 번역, 오답 진단을 함께 적는다.
# - 손계산이 필요한 문항은 중간 과정과 판정 근거를 남긴다.
#
# - 의사결정/경영과학 문맥의 용어만 사용한다.

# %% [markdown]
# ## 2. 채점 기준
#
# - Big-M formulation과 부호 판정: 25점
# - artificial variable 동치 조건 해석: 20점
# - dual problem 작성과 primal-dual mapping: 25점
# - weak/strong duality 및 complementary slackness 판정: 15점
# - reduced cost/shadow price 연결: 5점
# - source anchor/node_id 사용: 10점

# %% [markdown]
# ## 3. 문제 세트

# %% [markdown]
# ### 문항 1. min 문제를 Big-M용 max 형태로 바꾸기
#
# 다음 최소화 문제를 Big-M 접근을 위한 max 형태로 변환한다고 하자.
#
# ```text
# Minimize Z = 4x1 + 5x2
# subject to
# 2x1 + x2 >= 12
# x1 + 3x2 >= 15
# x1, x2 >= 0
# ```
#
# 요구:
#
# 1. `-Z`를 최대화하는 형태로 목적함수를 바꾸라.
# 2. 각 제약에 surplus/artificial variable을 도입하라.
# 3. artificial variable에 Big-M penalty를 붙일 때 부호를 판정하라.
#
# - node_id: `n_DM_PDF05.big_m_method`, `n_DM_PDF05.artificial_variable`
# - source anchors: `DM_PDF05:p002:L002`, `DM_PDF05:p003:L009`, `DM_PDF05:p003:L016`

# %%
# 힌트:
# - min Z는 max -Z로 바꿔 볼 수 있다.
# - >= 제약은 surplus를 빼고 artificial을 더한다.
# - max 형태에서 artificial이 남으면 불리하도록 M penalty 부호를 둔다.

# %% [markdown]
# ### 내 답안
#
# - max 변환:
# - 표준형:
# - Big-M 목적행:
# - 부호 판정 이유:
# - 근거 anchors:

# %% [markdown]
# ### 문항 2. artificial variable 동치 조건
#
# Big-M 모형에서 artificial variable `r1`, `r2`가 도입되었다.
#
# 요구:
#
# 1. `r1=0`, `r2=0`이어야 원문제와 동치라고 말하는 이유를 설명하라.
# 2. 반복 중 `r1`, `r2`가 모두 비기저변수가 되면 무엇을 의미하는지 설명하라.
# 3. `r1>0`인 해를 원문제 해로 해석하면 왜 안 되는지 설명하라.
#
# - node_id: `n_DM_PDF05.artificial_variable`, `n_DM_PDF05.big_m_method`
# - source anchors: `DM_PDF05:p003:L015`, `DM_PDF05:p007:L003`

# %%
# 힌트:
# - artificial variable은 원문제에는 없던 임시 변수다.
# - 최종해에서 artificial이 양수이면 원 제약만으로는 그 해를 만들 수 없다.
# - 비기저 artificial은 값이 0이다.

# %% [markdown]
# ### 내 답안
#
# - 동치 조건:
# - 비기저가 된 의미:
# - r>0 해석 금지 이유:
# - 근거 anchors:

# %% [markdown]
# ### 문항 3. Big-M과 2단계법 비교
#
# 2단계법과 Big-M 방법은 모두 artificial variable을 다룬다.
#
# 요구:
#
# 1. 두 방법의 공통 목적을 설명하라.
# 2. Phase I objective와 Big-M penalty의 차이를 설명하라.
# 3. 어떤 점에서 Big-M은 계산상 부호 오류에 취약한지 설명하라.
#
# - node_id: `n_DM_PDF05.big_m_method`, `n_DM_PDF01.two_phase_method`
# - source anchors: `DM_PDF05:p004:L002`, `DM_PDF01:p005:L001`

# %%
# 힌트:
# - 두 방법 모두 artificial을 0으로 만드는 것이 핵심이다.
# - 2단계법은 Phase I 목적함수를 따로 둔다.
# - Big-M은 원 목적함수에 큰 벌점을 한 번에 넣는다.

# %% [markdown]
# ### 내 답안
#
# - 공통 목적:
# - 차이점:
# - Big-M 부호 위험:
# - 근거 anchors:

# %% [markdown]
# ### 문항 4. Big-M 오답 진단
#
# 학생 답안:
#
# > “Max 형태에서 artificial variable은 목적함수에 `+M r1 + M r2`로 넣으면 더 빨리 basis에서 빠진다.”
#
# 요구:
#
# 1. 맞는 부분이 있는지 말하라.
# 2. 위험한 부분 또는 틀린 부분을 지적하라.
# 3. Big-M penalty의 목적을 설명하라.
# 4. 부호를 확인하는 안전한 절차를 제시하라.
#
# - node_id: `n_DM_PDF05.big_m_method`
# - source anchor: `DM_PDF05:p003:L016`

# %%
# 힌트:
# - M은 artificial을 남기지 않기 위한 큰 벌점이다.
# - max 문제에서 artificial을 보상하면 오히려 남기려 할 수 있다.
# - 항상 목적 방향과 penalty의 효과를 말로 번역해 확인한다.

# %% [markdown]
# ### 내 답안
#
# - 맞는 부분:
# - 오류/위험:
# - penalty 목적:
# - 안전한 부호 확인 절차:
# - 근거 anchor:

# %% [markdown]
# ### 문항 5. 식단문제와 비타민 가격 쌍대 직관
#
# 식단문제의 원문제는 필요한 영양소를 최소비용으로 충족하는 문제이고, 쌍대문제는 비타민 알약 가격결정 문제로 해석될 수 있다.
#
# 요구:
#
# 1. 원문제의 decision variable과 dual variable이 각각 무엇을 의미하는지 설명하라.
# 2. 원문제의 영양소 요구량 제약이 dual에서 어떤 역할을 하는지 설명하라.
# 3. 왜 모든 dual 문제의 현실 의미가 항상 명확하지는 않은지 설명하라.
#
# - node_id: `n_DM_PDF05.dual_problem`
# - source anchors: `DM_PDF05:p014:L001`, `DM_PDF05:p018:L001`, `DM_PDF05:p019:L001`

# %%
# 힌트:
# - 원문제 변수는 식품량이다.
# - dual 변수는 영양소 또는 자원의 가격으로 해석될 수 있다.
# - 쌍대의 수학적 존재와 현실적 해석 가능성은 구분한다.

# %% [markdown]
# ### 내 답안
#
# - primal variable 의미:
# - dual variable 의미:
# - 영양소 제약의 dual 역할:
# - 현실 해석 주의:
# - 근거 anchors:

# %% [markdown]
# ### 문항 6. primal-dual 대응표 작성
#
# 다음 primal 문제를 보라.
#
# ```text
# Maximize Z = 30x1 + 20x2
# subject to
# 8x1 + 4x2 <= 240
# 4x1 + 4x2 <= 200
# 4x1 + 0x2 <= 100
# x2 <= 40
# x1, x2 >= 0
# ```
#
# 요구:
#
# 1. 각 primal 제약에 대응하는 dual variable을 정의하라.
# 2. dual objective를 쓰라.
# 3. `x1`에 대응하는 dual constraint를 쓰라.
# 4. `x2`에 대응하는 dual constraint를 쓰라.
# 5. dual variable의 비음조건을 쓰라.
#
# - node_id: `n_DM_PDF05.dual_problem`, `n_DM_PDF05.primal_dual_mapping`
# - source anchor: `DM_PDF05:p023:L002`

# %%
# 힌트:
# - max primal의 <= 제약은 보통 nonnegative dual variable로 대응한다.
# - primal RHS는 dual objective coefficient가 된다.
# - primal 변수 하나는 dual constraint 하나에 대응한다.

# %% [markdown]
# ### 내 답안
#
# - dual variables:
# - dual objective:
# - x1 대응 dual constraint:
# - x2 대응 dual constraint:
# - dual variable domain:
# - 근거 anchor:

# %% [markdown]
# ### 문항 7. 약쌍대성 판정
#
# 다음 두 가능해가 주어졌다.
#
# ```text
# Primal feasible solution의 목적값 Z = 700
# Dual feasible solution의 목적값 W = 1540
# ```
#
# 요구:
#
# 1. max primal / min dual 구조에서 이 관계가 약쌍대성을 만족하는지 판정하라.
# 2. 왜 `Z <= W`이어야 하는지 설명하라.
# 3. `Z = W`이면 무엇을 말할 수 있는지 설명하라.
#
# - node_id: `n_DM_PDF05.weak_duality`, `n_DM_PDF05.strong_duality`
# - source anchor: `DM_PDF05:p024:L001`

# %%
# 힌트:
# - weak duality는 임의의 primal feasible 값이 dual feasible 값보다 클 수 없다는 명제다.
# - 값이 같아지면 strong duality와 최적성 판정으로 이어진다.

# %% [markdown]
# ### 내 답안
#
# - 약쌍대성 만족 여부:
# - Z <= W 이유:
# - Z = W 의미:
# - 근거 anchor:

# %% [markdown]
# ### 문항 8. 강쌍대성과 최적성
#
# 다음 문장을 판정하라.
#
# A. 원문제와 쌍대문제가 모두 feasible이고, 각각 최적해를 가지며 목적값이 같다.
#
# B. 원문제의 한 feasible solution 값이 dual feasible solution 값보다 작다.
#
# C. 원문제가 unbounded이면 dual은 infeasible일 수 있다.
#
# 요구:
#
# 1. 각 문장을 weak duality, strong duality, 4 cases 중 어디에 연결할지 쓰라.
# 2. 최적해 판정에 필요한 조건을 설명하라.
#
# - node_id: `n_DM_PDF05.weak_duality`, `n_DM_PDF05.strong_duality`, `n_DM_PDF05.four_duality_cases`
# - source anchors: `DM_PDF05:p024:L001`, `DM_PDF05:p025:L001`

# %%
# 힌트:
# - 목적값의 부등식은 weak duality다.
# - 최적값 일치는 strong duality다.
# - unbounded/infeasible 관계는 4 cases와 연결한다.

# %% [markdown]
# ### 내 답안
#
# - A 연결:
# - B 연결:
# - C 연결:
# - 최적해 판정 조건:
# - 근거 anchors:

# %% [markdown]
# ### 문항 9. 상보여유 기초 판정
#
# 다음 조건이 주어졌다.
#
# ```text
# Primal constraint 2 has slack = 40.
# Dual variable y2 = 3.
# ```
#
# 요구:
#
# 1. complementary slackness를 만족하는지 판정하라.
# 2. 만족하지 않는다면 어느 값이 0이어야 하는지 쓰라.
# 3. “binding constraint와 positive shadow price”의 관계로 설명하라.
#
# - node_id: `n_DM_PDF05.complementary_slackness`, `n_DM_PDF02.shadow_price`
# - source anchors: `DM_PDF05:p027:L001`, `DM_PDF05:p030:L002`

# %%
# 힌트:
# - 상보여유에서는 primal slack과 대응 dual variable의 곱이 0이어야 한다.
# - 제약에 여유가 있으면 그 자원의 잠재가격은 0이어야 한다.
# - positive shadow price는 보통 binding constraint와 연결된다.

# %% [markdown]
# ### 내 답안
#
# - 만족 여부:
# - 0이어야 하는 값:
# - binding/positive shadow price 해석:
# - 근거 anchors:

# %% [markdown]
# ### 문항 10. reduced cost와 shadow price 연결
#
# 다음 설명을 완성하라.
#
# > “한계비용은 최적해 타블로에서 원래 변수의 목적함수식 계수와 연결되고, 잠재가격은 여유변수 계수와 연결된다.”
#
# 요구:
#
# 1. reduced cost와 shadow price를 각각 어떤 질문에 답하는 값인지 구분하라.
# 2. 변수 질문과 제약/RHS 질문을 분리하라.
# 3. Big-M/duality 이후 sensitivity report로 넘어가는 연결을 설명하라.
#
# - node_id: `n_DM_PDF02.reduced_cost`, `n_DM_PDF02.shadow_price`
# - source anchor: `DM_PDF05:p032:L002`

# %%
# 힌트:
# - reduced cost는 변수/활동이 basis에 들어올 조건과 연결된다.
# - shadow price는 RHS 자원 1단위 변화의 가치와 연결된다.
# - 민감도 보고서는 이 정보를 Solver 출력으로 정리한다.

# %% [markdown]
# ### 내 답안
#
# - reduced cost가 답하는 질문:
# - shadow price가 답하는 질문:
# - 변수 질문 vs RHS 질문:
# - sensitivity report 연결:
# - 근거 anchor:

# %% [markdown]
# ### 문항 11. sensitivity report 브릿지 판별
#
# Big-M과 duality를 배운 뒤 다음 Phase에서는 sensitivity analysis로 넘어간다.
#
# 다음 질문을 reduced cost 질문인지, shadow price 질문인지 구분하라.
#
# A. 현재 해에서 생산하지 않는 활동을 새로 시작하려면 목적계수가 얼마나 좋아져야 하는가?
# B. 원료 1단위를 더 확보하면 최적 목적값은 얼마나 변하는가?
# C. 어떤 변수의 값이 0인 이유가 목적계수 때문인지 알고 싶다.
# D. 어떤 제약 RHS를 바꿔도 현재 basis 해석이 유지되는 범위를 알고 싶다.
#
# 요구:
#
# 1. A~D를 reduced cost 또는 shadow price/allowable range 질문으로 분류하라.
# 2. 왜 이 구분이 primal-dual 해석 이후에 자연스럽게 등장하는지 설명하라.
# 3. 다음 Phase에서 sensitivity report를 볼 때 먼저 확인할 열 이름을 쓰라.
#
# - node_id: `n_DM_PDF02.reduced_cost`, `n_DM_PDF02.shadow_price`, `n_DM_PDF05.shadow_price_dual_solution`
# - source anchors: `DM_PDF05:p032:L002`, `DM_PDF02:p026:L007`, `DM_PDF02:p026:L009`

# %%
# 힌트:
# - reduced cost는 변수/활동 질문이다.
# - shadow price는 제약/RHS/자원 질문이다.
# - allowable range는 그 해석이 유효한 범위를 묻는다.

# %% [markdown]
# ### 내 답안
#
# - A~D 분류:
# - primal-dual 이후 등장하는 이유:
# - sensitivity report에서 볼 열:
# - 근거 anchors:

# %% [markdown]
# ### 문항 12. 최종 종합 문제
#
# 이번 Phase를 다음 개념 그래프로 정리하라.
#
# ```text
# artificial variable -> Big-M -> primal-dual mapping -> weak duality -> strong duality -> complementary slackness -> sensitivity report
# ```
#
# 요구:
#
# 1. 각 노드를 한 문장으로 정의하라.
# 2. 각 노드 사이의 연결 이유를 쓰라.
# 3. 다음 Phase에서 sensitivity analysis로 넘어가야 하는 이유를 쓰라.
#
# - node_id: `n_DM_PDF05.artificial_variable`, `n_DM_PDF05.big_m_method`, `n_DM_PDF05.dual_problem`, `n_DM_PDF05.complementary_slackness`, `n_DM_PDF02.shadow_price`
# - source anchors: `DM_PDF05:p003:L009`, `DM_PDF05:p023:L002`, `DM_PDF05:p024:L001`, `DM_PDF05:p027:L001`, `DM_PDF05:p032:L002`

# %%
# 힌트:
# - artificial은 실행가능 출발점을 만들기 위한 임시 변수다.
# - Big-M은 artificial을 벌점으로 제거한다.
# - duality는 제약과 변수의 경제적 의미를 연결하고 sensitivity report로 이어진다.

# %% [markdown]
# ### 내 답안
#
# - 노드별 한 문장 정의:
# - 연결 이유:
# - 다음 Phase 연결:
# - 근거 anchors:
