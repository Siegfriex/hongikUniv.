# %% [markdown]
# # DM_G1_P0002
#
# ## 0. 학습 범위
#
# - Gate: G1
# - Phase: P0002
# - Topic: 2단계법과 artificial variable
# - Goal: 초기 기저가능해가 없을 때 surplus/artificial variable을 도입하고 Phase I/Phase II 전환을 설명한다.
# - Source basis:
#   - `DM_PDF01__04_rag.md`
#   - `DM_PDF01__03_concept_node_index.md`
#   - `DM_PDF01__02_rawdata_develop.md`
#   - `DM_PDF01__01_pdf_transcript.md`
#   - `DM_PDF05__04_rag.md`
# - Output language: Korean
# - Code mode: hint_only

# %% [markdown]
# ## 1. 작성 규칙
#
# - 풀이용 노트북에는 최종 정답을 적지 않는다.
# - 각 문항의 `node_id`와 `source anchor`를 확인한 뒤 답안을 작성한다.
# - 계산보다 판정 이유, Solver 번역, 오답 진단을 함께 적는다.
# - 손계산이 필요한 문항은 중간 과정과 판정 근거를 남긴다.

# %% [markdown]
# ## 2. 채점 기준
#
# - slack/surplus/artificial variable 도입: 25점
# - Phase I objective와 종료조건 해석: 25점
# - Phase II 전환 설명: 20점
# - Solver mapping: 10점
# - 오답 진단과 현실 언어 번역: 10점
# - source anchor/node_id 사용: 10점

# %% [markdown]
# ## 3. 문제 세트

# %% [markdown]
# ### 문항 1. surplus/artificial variable 도입 판별
#
# 다음 제약식을 표준형으로 바꾸는 방법을 판별하라.
#
# ```text
# x1 + 2x2 <= 8
# 2x1 + x2 >= 10
# x1 + x2 = 7
# x1, x2 >= 0
# ```
#
# 요구:
#
# 1. 각 행에 필요한 slack, surplus, artificial variable을 쓰라.
# 2. 각 행의 표준형을 쓰라.
# 3. 초기 기저변수 후보를 쓰라.
# 4. artificial variable이 필요한 행과 이유를 쓰라.
#
# - node_id: `n_DM_PDF01.surplus_artificial_variable`
# - source anchor: `DM_PDF01:p004:L003`

# %%
# 힌트:
# - <= 제약은 slack을 더한다.
# - >= 제약은 surplus를 빼고 artificial을 더한다.
# - = 제약은 초기 basis가 없으면 artificial을 더한다.

# %% [markdown]
# ### 내 답안
#
# - 1행 표준형:
# - 2행 표준형:
# - 3행 표준형:
# - 초기 기저변수 후보:
# - artificial 필요 행과 이유:
# - 근거 anchor:

# %% [markdown]
# ### 문항 2. 2단계법 문제 변형
#
# 다음 문제를 2단계법으로 풀기 위한 표준형으로 바꾸라.
#
# Maximize `z = 3x1 + 2x2`
#
# subject to
#
# ```text
# x1 + 2x2 <= 8
# 2x1 + x2 >= 10
# x1 + x2 = 7
# x1, x2 >= 0
# ```
#
# 요구:
#
# 1. slack/surplus/artificial variable을 도입하라.
# 2. Phase I objective `w`를 쓰라.
# 3. Phase I의 초기 기저변수를 쓰라.
# 4. Phase II로 넘어가기 위한 조건을 쓰라.
#
# - node_id: `n_DM_PDF01.two_phase_method`
# - source anchors: `DM_PDF01:p004:L002`, `DM_PDF01:p005:L001`

# %%
# 힌트:
# - Phase I의 목적은 artificial variable의 합을 최소화하는 것이다.
# - 원래 max z는 Phase II에서 다시 사용한다.
# - w*=0인지 확인해야 한다.

# %% [markdown]
# ### 내 답안
#
# - 표준형:
# - Phase I objective:
# - Phase I 초기 기저변수:
# - Phase II 전환 조건:
# - 근거 anchors:

# %% [markdown]
# ### 문항 3. Phase I 목적함수 해석
#
# 학생이 다음과 같이 답했다.
#
# > “Phase I에서 w=0이 나왔으므로 원문제의 최적 목적값은 0이다.”
#
# 요구:
#
# 1. 맞는 부분이 있는지 말하라.
# 2. 틀린 이유를 설명하라.
# 3. `w=0`이 실제로 의미하는 것을 쓰라.
# 4. Phase II에서 무엇을 해야 하는지 쓰라.
#
# - node_id: `n_DM_PDF01.two_phase_method`
# - source anchor: `DM_PDF01:p006:L001`

# %%
# 힌트:
# - w는 artificial variable의 합이다.
# - w=0은 원문제 feasible basis 존재를 뜻한다.
# - 원래 목적함수 z의 최적값은 Phase II에서 구한다.

# %% [markdown]
# ### 내 답안
#
# - 맞는 부분:
# - 틀린 이유:
# - w=0의 의미:
# - Phase II에서 할 일:
# - 근거 anchor:

# %% [markdown]
# ### 문항 4. artificial variable 최종해 판정
#
# 다음 두 상황을 판정하라.
#
# 상황 A: Phase I 최적해에서 `w*=0`, artificial variables는 모두 비기저변수이다.
#
# 상황 B: Phase I 최적해에서 `w*=3`, artificial variable `a2=3`이 기저변수로 남아 있다.
#
# 요구:
#
# 1. 각 상황에서 원문제 feasible 여부를 판정하라.
# 2. Phase II 진행 가능 여부를 쓰라.
# 3. artificial variable이 양수로 남는다는 말의 현실적 의미를 설명하라.
#
# - node_id: `n_DM_PDF01.two_phase_method`, `n_DM_PDF05.artificial_variable`
# - source anchors: `DM_PDF01:p006:L001`, `DM_PDF05:p007:L003`

# %%
# 힌트:
# - artificial variables가 모두 0이면 원문제 제약만으로 basis를 구성할 수 있다.
# - w*>0이면 artificial이 사라지지 못한 것이다.
# - artificial은 현실 decision variable이 아니라 임시 계산 변수다.

# %% [markdown]
# ### 내 답안
#
# - 상황 A 판정:
# - 상황 B 판정:
# - Phase II 가능 여부:
# - 현실적 의미:
# - 근거 anchors:

# %% [markdown]
# ### 문항 5. 식단문제 축소형
#
# 다음 축소 식단문제를 2단계법 관점에서 모형화하라.
#
# 식품 1,2,3이 있고, 각 100g당 비용은 300, 400, 500원이다. 비타민 A 함량은 10, 20, 10이고 하루 요구량은 50 이상이다. 비타민 C 함량은 0, 10, 30이고 하루 요구량은 60 이상이다.
#
# 요구:
#
# 1. decision variables를 정의하라.
# 2. 원문제의 objective function을 쓰라.
# 3. 두 영양소 constraints를 쓰라.
# 4. surplus/artificial variable을 포함한 표준형을 쓰라.
# 5. Phase I objective를 쓰라.
#
# - node_id: `n_DM_PDF01.diet_two_phase`
# - source anchors: `DM_PDF01:p007:L001`, `DM_PDF01:p008:L001`

# %%
# 힌트:
# - 식품량은 decision variables다.
# - 최소 요구량 이상은 >= 제약이다.
# - >= 제약은 surplus를 빼고 artificial을 더해 Phase I basis를 만든다.

# %% [markdown]
# ### 내 답안
#
# - decision variables:
# - objective:
# - 원 제약식:
# - 표준형:
# - Phase I objective:
# - 근거 anchors:

# %% [markdown]
# ### 문항 6. Phase II 전환 구조
#
# 문항 5의 Phase I에서 artificial variables가 모두 비기저변수가 되었다고 가정한다.
#
# 요구:
#
# 1. 제거해야 하는 변수는 무엇인가?
# 2. Phase II에서 다시 넣어야 하는 목적함수는 무엇인가?
# 3. Phase I의 basis를 Phase II의 초기 basis로 쓰는 이유를 설명하라.
#
# - node_id: `n_DM_PDF01.two_phase_method`
# - source anchors: `DM_PDF01:p006:L001`, `DM_PDF01:p009:L001`

# %%
# 힌트:
# - Phase I 종료 후 artificial variable 열을 제거한다.
# - Phase II는 원래 목적함수로 돌아간다.
# - Phase I에서 얻은 feasible basis가 Phase II의 출발점이 된다.

# %% [markdown]
# ### 내 답안
#
# - 제거 변수:
# - Phase II 목적함수:
# - basis를 이어 쓰는 이유:
# - 근거 anchors:

# %% [markdown]
# ### 문항 7. 오답 진단: surplus 부호
#
# 학생 답안:
#
# > “`2x1 + x2 >= 10`은 `2x1 + x2 + s1 + a1 = 10`으로 바꾸면 된다.”
#
# 요구:
#
# 1. 오류 위치를 지적하라.
# 2. 올바른 표준형을 쓰라.
# 3. 왜 surplus variable은 빼야 하는지 현실 언어로 설명하라.
# 4. artificial variable이 왜 다시 필요한지 설명하라.
#
# - node_id: `n_DM_PDF01.surplus_artificial_variable`
# - source anchor: `DM_PDF01:p004:L003`

# %%
# 힌트:
# - >= 제약은 좌변이 RHS를 초과하는 양을 surplus로 뺀다.
# - artificial은 초기 basis를 만들기 위한 임시 변수다.
# - slack과 surplus의 부호를 구분한다.

# %% [markdown]
# ### 내 답안
#
# - 오류 위치:
# - 올바른 표준형:
# - surplus를 빼는 현실적 의미:
# - artificial이 필요한 이유:
# - 근거 anchor:

# %% [markdown]
# ### 문항 8. Solver 매핑 문제
#
# 식단형 최소화 문제를 Excel Solver로 직접 푼다고 할 때 다음을 답하라.
#
# 1. changing cells는 무엇인가?
# 2. target cell은 무엇인가?
# 3. constraint cells는 무엇인가?
# 4. `>=` 제약이 Solver에서는 어떻게 입력되는가?
# 5. 수동 2단계법과 Solver의 차이를 설명하라.
#
# - node_id: `n_DM_PDF01.diet_two_phase`
# - source anchor: `DM_PDF01:p007:L001`

# %%
# 힌트:
# - Solver에서는 artificial variable을 사용자가 직접 만들지 않아도 된다.
# - changing cells는 식품량이다.
# - target cell은 총비용이고 constraint cells는 영양소 섭취량 계산 셀이다.

# %% [markdown]
# ### 내 답안
#
# - changing cells:
# - target cell:
# - constraint cells:
# - >= 입력 방식:
# - 수동 2단계법과 Solver 차이:
# - 근거 anchor:

# %% [markdown]
# ### 문항 9. Phase I tableau 해석
#
# 다음 문장을 보고 판단하라.
#
# > “Phase I 마지막 타블로에서 objective value는 0이고 artificial variables는 모두 nonbasic이다.”
#
# 요구:
#
# 1. 이 상태가 뜻하는 바를 쓰라.
# 2. 이때 원래 문제의 최적해가 이미 구해진 것인지 판정하라.
# 3. 다음 단계에서 tableau에서 제거해야 하는 열을 쓰라.
#
# - node_id: `n_DM_PDF01.two_phase_method`
# - source anchor: `DM_PDF01:p006:L001`

# %%
# 힌트:
# - objective value 0은 Phase I 목적함수 w에 대한 값이다.
# - 원문제 feasible basis를 얻었다는 뜻이지 원 목적 z의 최적해를 얻었다는 뜻은 아니다.
# - artificial variable 열을 제거한다.

# %% [markdown]
# ### 내 답안
#
# - 상태의 의미:
# - 원문제 최적해 여부:
# - 제거할 열:
# - 근거 anchor:

# %% [markdown]
# ### 문항 10. 최종 종합 문제
#
# 다음 용어를 한 문장씩 설명하고, 서로의 연결 관계를 화살표로 그려라.
#
# - slack variable
# - surplus variable
# - artificial variable
# - Phase I
# - Phase II
# - feasible basis
# - infeasible original problem
#
# - node_id: `n_DM_PDF01.surplus_artificial_variable`, `n_DM_PDF01.two_phase_method`
# - source anchors: `DM_PDF01:p004:L003`, `DM_PDF01:p005:L001`, `DM_PDF01:p006:L001`

# %%
# 힌트:
# - slack/surplus는 부등호를 등식으로 바꾸는 변수다.
# - artificial은 초기 basis를 만들기 위한 임시 변수다.
# - Phase I은 artificial을 0으로 만들 수 있는지 확인한다.

# %% [markdown]
# ### 내 답안
#
# - 용어 정의:
# - 연결 화살표:
# - feasible/infeasible 판정:
# - 근거 anchors:
